# %%
import sys, time

# %%
sys.path.append('..')

# %%
from pathlib import Path

import matplotlib
import matplotlib.pyplot as plt

import torch

import numpy as np
import pandas as pd
import pickle as pkl

import gym

import autotrain
import autotrain.gym_env 
import autotrain.agent.replay_memory as replay_memory

# if gpu is to be used
DEVICE = torch.device("cuda:3")

# %%
results_path = Path('./results')

# %%
proto_path = results_path / 'full_min_proto_0_cifar_clone'

# %%
parse = lambda s: int(s.name.split('_')[0])

# %%
sorted(parse(p) for p in list(proto_path.iterdir()))[-10:]
# Out:
# [148, 149, 150, 151, 152, 153, 154, 155, 156, 157]

# %%
episode_path = proto_path / '155_episode'

# %%
list(episode_path.iterdir())
# Out:
# [PosixPath('results/full_min_proto_0_cifar_clone/155_episode/policy_net.ckpt'),
#  PosixPath('results/full_min_proto_0_cifar_clone/155_episode/env_params.pkl'),
#  PosixPath('results/full_min_proto_0_cifar_clone/155_episode/replay_buffer.pkl'),
#  PosixPath('results/full_min_proto_0_cifar_clone/155_episode/env_loss.pkl'),
#  PosixPath('results/full_min_proto_0_cifar_clone/155_episode/target_net.ckpt'),
#  PosixPath('results/full_min_proto_0_cifar_clone/155_episode/env_mdp_log.csv')]

# %%
mdpdf = pd.read_csv(episode_path / 'env_mdp_log.csv')

# %%
T = batch updates = 1 poch
weights = n*T

# %%
phi_0 = 0
phi_1 = ph
delta > 0

# %%
1 optimisation

# %%
mdpdf
# Out:
#     Unnamed: 0     t       phi    reward                             action  \
# 0            0   0.0  0.106700  0.000000                           ENV INIT
# 1            1   1.0  0.676574  0.050000     keep current lr && rewind by 1
# 2            2   2.0  0.681084  0.050000  decrease lr by 10% && rewind by 4
# 3            3   3.0  0.684033  0.050000  decrease lr by 10% && rewind by 4
# 4            4   4.0  0.680986  0.050000  decrease lr by 10% && rewind by 4
# 5            5   5.0  0.679057  0.050000  decrease lr by 10% && rewind by 4
# 6            6   6.0  0.679737  0.050000  decrease lr by 10% && rewind by 4
# 7            7   7.0  0.665545  0.050000  decrease lr by 10% && rewind by 4
# 8            8   8.0  0.685340  0.050000  decrease lr by 10% && rewind by 4
# 9            9   9.0  0.689905  0.050000  decrease lr by 10% && rewind by 4
# 10          10  10.0  0.672707  0.050000  decrease lr by 10% && rewind by 4
# ...

# %%
with (episode_path / 'env_mdp_log.csv').open('rb') as fp:
    mem = pkl.load(fp)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-68-85e9b67f4d07> in <module>
#       1 with (episode_path / 'env_mdp_log.csv').open('rb') as fp:
# ----> 2     mem = pkl.load(fp)
#
# UnpicklingError: invalid load key, ','.

# %%
dir(mem)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
type(mem)
# Out:
# list

# %%
len(mem)
# Out:
# 6297

# %%
# together we have around 14k samples

# %%
'env_mdp_log.csv'
